# %% [markdown]
# # Training Atari Breakout with Stable Baseline 3.
#
# <font color="red"> If GPU cannot be allocated due to high usage, change it to CPU.
#
# While CPU is slower than GPU (about 1~1.5 times), it can still works well. </font>
#
# **Stable Baselines3** is a set of reliable implementations of reinforcement learning algorithms in PyTorch, which makes us easy to build and test RL algorithms! This package contain several RL algorithms, including DQN, A2C, DDPG, PPO, SAC, and TD3, along with useful function and wrappers for RL experiments.

# %% [markdown]
# 1. Start with installing required packages and importing libraries

# %%
# !pip install -q gym
# !pip install -q stable-baselines3[extra]

import gymnasium as gym
from stable_baselines3 import PPO, A2C, DQN
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
from stable_baselines3.common.env_util import make_atari_env, make_vec_env

import os
os.system("Xvfb :1 -screen 0 1024x768x24 &")
os.environ['DISPLAY'] = ':1'
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 28.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 46.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/farama-notifications/
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 67.4 MB/s eta 0:00:00
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done

# %% [markdown]
# # Algorithms
# 1. DQN: Deep Q-Network aims to find the best action to take in a given state by estimating the Q-values. (https://arxiv.org/abs/1312.5602)
# 2. A2C: Advantage Actor Critic (A2C) is a reinforcement learning algorithm that combines actor and critic networks. It operates synchronously and deterministically, making it easier to understand and implement. Unlike DQN, it doesn't use a replay buffer but employs multiple workers to gather experience. (https://arxiv.org/abs/1602.01783)
# 3. PPO: Proximal Policy Optimization (PPO) is an algorithm that blends ideas from A2C (using multiple workers) and TRPO (trust region policy optimization). It seeks to optimize policy parameters to improve the actor's performance. PPO uses a trust region to control how much the policy is updated, making it more stable during training.(https://arxiv.org/abs/1707.06347)

# %% [markdown]
# 2. Select RL algorithm and set hyperparameters.

# %%
import os
algorithm = "DQN" # change this to change the algorithm

log_dir = "./DQN_CNN_ALE"
os.makedirs(log_dir, exist_ok=True)
vec_env = make_atari_env("BreakoutDeterministic-v4", n_envs=4) # 4 multiple environments (vector input)
vec_env = VecFrameStack(vec_env, n_stack=4)

if algorithm == "DQN":
  model = DQN("CnnPolicy", vec_env, verbose=1, learning_rate=1e-5, buffer_size=1000000, learning_starts=10000, batch_size=32, gamma=0.99, train_freq=4, target_update_interval=2500, exploration_fraction=0.2, exploration_initial_eps=1.0, exploration_final_eps=0.05)
elif algorithm == "A2C":
  model = A2C("CnnPolicy", vec_env, verbose=1)
elif  algorithm == "PPO":
  model = PPO("CnnPolicy", vec_env, verbose=1)
else:
  raise Exception("not supported algorithm")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/buffers.py:231: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 56.46GB > 12.17GB
#   warnings.warn(

# %% [markdown]
# 4. Let's begin training!

# %%
model.learn(total_timesteps=200000)
model.save("DQN_CNN_ALE_last")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# |    episodes         | 15596    |
# |    fps              | 175      |
# |    time_elapsed     | 801      |
# |    total_timesteps  | 141072   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0223   |
# |    n_updates        | 8191     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 259      |
# |    ep_rew_mean      | 2.84     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15600    |
# |    fps              | 175      |
# |    time_elapsed     | 801      |
# |    total_timesteps  | 141124   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0377   |
# |    n_updates        | 8195     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 259      |
# |    ep_rew_mean      | 2.84     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15604    |
# |    fps              | 175      |
# |    time_elapsed     | 802      |
# |    total_timesteps  | 141176   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0109   |
# |    n_updates        | 8198     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 259      |
# |    ep_rew_mean      | 2.84     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15608    |
# |    fps              | 175      |
# |    time_elapsed     | 802      |
# |    total_timesteps  | 141188   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0212   |
# |    n_updates        | 8199     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 261      |
# |    ep_rew_mean      | 2.87     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15612    |
# |    fps              | 175      |
# |    time_elapsed     | 802      |
# |    total_timesteps  | 141216   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0468   |
# |    n_updates        | 8200     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 262      |
# |    ep_rew_mean      | 2.92     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15616    |
# |    fps              | 175      |
# |    time_elapsed     | 802      |
# |    total_timesteps  | 141268   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0305   |
# |    n_updates        | 8204     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 262      |
# |    ep_rew_mean      | 2.92     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15620    |
# |    fps              | 176      |
# |    time_elapsed     | 802      |
# |    total_timesteps  | 141320   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.028    |
# |    n_updates        | 8207     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 262      |
# |    ep_rew_mean      | 2.92     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15624    |
# |    fps              | 176      |
# |    time_elapsed     | 803      |
# |    total_timesteps  | 141344   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.088    |
# |    n_updates        | 8208     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 262      |
# |    ep_rew_mean      | 2.92     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15628    |
# |    fps              | 176      |
# |    time_elapsed     | 803      |
# |    total_timesteps  | 141380   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0895   |
# |    n_updates        | 8211     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 263      |
# |    ep_rew_mean      | 2.96     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15632    |
# |    fps              | 176      |
# |    time_elapsed     | 803      |
# |    total_timesteps  | 141428   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0703   |
# |    n_updates        | 8214     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 265      |
# |    ep_rew_mean      | 2.99     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15636    |
# |    fps              | 176      |
# |    time_elapsed     | 803      |
# |    total_timesteps  | 141496   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0601   |
# |    n_updates        | 8218     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 265      |
# |    ep_rew_mean      | 2.99     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15640    |
# |    fps              | 176      |
# |    time_elapsed     | 804      |
# |    total_timesteps  | 141608   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0777   |
# |    n_updates        | 8225     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 266      |
# |    ep_rew_mean      | 3.01     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15644    |
# |    fps              | 176      |
# |    time_elapsed     | 804      |
# |    total_timesteps  | 141656   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0413   |
# |    n_updates        | 8228     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 266      |
# |    ep_rew_mean      | 3.01     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15648    |
# |    fps              | 176      |
# |    time_elapsed     | 804      |
# |    total_timesteps  | 141692   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0478   |
# |    n_updates        | 8230     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 266      |
# |    ep_rew_mean      | 3.01     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15652    |
# |    fps              | 176      |
# |    time_elapsed     | 804      |
# |    total_timesteps  | 141752   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0651   |
# |    n_updates        | 8234     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 271      |
# |    ep_rew_mean      | 3.16     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15656    |
# |    fps              | 176      |
# |    time_elapsed     | 805      |
# |    total_timesteps  | 141808   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0698   |
# |    n_updates        | 8237     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 271      |
# |    ep_rew_mean      | 3.16     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15660    |
# |    fps              | 176      |
# |    time_elapsed     | 805      |
# |    total_timesteps  | 141836   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0661   |
# |    n_updates        | 8239     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 271      |
# |    ep_rew_mean      | 3.16     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15664    |
# |    fps              | 176      |
# |    time_elapsed     | 805      |
# |    total_timesteps  | 141892   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.046    |
# |    n_updates        | 8243     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 271      |
# |    ep_rew_mean      | 3.16     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15668    |
# |    fps              | 176      |
# |    time_elapsed     | 805      |
# |    total_timesteps  | 141940   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0684   |
# |    n_updates        | 8246     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 274      |
# |    ep_rew_mean      | 3.23     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15672    |
# |    fps              | 176      |
# |    time_elapsed     | 806      |
# |    total_timesteps  | 141988   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0627   |
# |    n_updates        | 8249     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 274      |
# |    ep_rew_mean      | 3.23     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15676    |
# |    fps              | 176      |
# |    time_elapsed     | 806      |
# |    total_timesteps  | 142020   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0351   |
# |    n_updates        | 8251     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 274      |
# |    ep_rew_mean      | 3.24     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15680    |
# |    fps              | 176      |
# |    time_elapsed     | 806      |
# |    total_timesteps  | 142064   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0376   |
# |    n_updates        | 8253     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 274      |
# |    ep_rew_mean      | 3.24     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15684    |
# |    fps              | 176      |
# |    time_elapsed     | 806      |
# |    total_timesteps  | 142096   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0112   |
# |    n_updates        | 8255     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 274      |
# |    ep_rew_mean      | 3.24     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15688    |
# |    fps              | 176      |
# |    time_elapsed     | 806      |
# |    total_timesteps  | 142152   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0158   |
# |    n_updates        | 8259     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 274      |
# |    ep_rew_mean      | 3.24     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15692    |
# |    fps              | 176      |
# |    time_elapsed     | 807      |
# |    total_timesteps  | 142176   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.108    |
# |    n_updates        | 8260     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 274      |
# |    ep_rew_mean      | 3.23     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15696    |
# |    fps              | 176      |
# |    time_elapsed     | 807      |
# |    total_timesteps  | 142232   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0357   |
# |    n_updates        | 8264     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 274      |
# |    ep_rew_mean      | 3.24     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15700    |
# |    fps              | 176      |
# |    time_elapsed     | 807      |
# |    total_timesteps  | 142256   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0348   |
# |    n_updates        | 8265     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 274      |
# |    ep_rew_mean      | 3.24     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15704    |
# |    fps              | 176      |
# |    time_elapsed     | 807      |
# |    total_timesteps  | 142288   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0288   |
# |    n_updates        | 8267     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 274      |
# |    ep_rew_mean      | 3.25     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15708    |
# |    fps              | 176      |
# |    time_elapsed     | 807      |
# |    total_timesteps  | 142348   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0617   |
# |    n_updates        | 8271     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 274      |
# |    ep_rew_mean      | 3.26     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15712    |
# |    fps              | 176      |
# |    time_elapsed     | 807      |
# |    total_timesteps  | 142368   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0393   |
# |    n_updates        | 8272     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 274      |
# |    ep_rew_mean      | 3.26     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15716    |
# |    fps              | 176      |
# |    time_elapsed     | 808      |
# |    total_timesteps  | 142428   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0516   |
# |    n_updates        | 8276     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 274      |
# |    ep_rew_mean      | 3.27     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15720    |
# |    fps              | 176      |
# |    time_elapsed     | 808      |
# |    total_timesteps  | 142452   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0446   |
# |    n_updates        | 8278     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 274      |
# |    ep_rew_mean      | 3.27     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15724    |
# |    fps              | 176      |
# |    time_elapsed     | 808      |
# |    total_timesteps  | 142484   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0265   |
# |    n_updates        | 8280     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 274      |
# |    ep_rew_mean      | 3.27     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15728    |
# |    fps              | 176      |
# |    time_elapsed     | 808      |
# |    total_timesteps  | 142508   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0612   |
# |    n_updates        | 8281     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 275      |
# |    ep_rew_mean      | 3.28     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15732    |
# |    fps              | 176      |
# |    time_elapsed     | 808      |
# |    total_timesteps  | 142548   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0338   |
# |    n_updates        | 8284     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 275      |
# |    ep_rew_mean      | 3.29     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15736    |
# |    fps              | 176      |
# |    time_elapsed     | 809      |
# |    total_timesteps  | 142592   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.033    |
# |    n_updates        | 8286     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 276      |
# |    ep_rew_mean      | 3.3      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15740    |
# |    fps              | 176      |
# |    time_elapsed     | 809      |
# |    total_timesteps  | 142616   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0717   |
# |    n_updates        | 8288     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 276      |
# |    ep_rew_mean      | 3.3      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15744    |
# |    fps              | 176      |
# |    time_elapsed     | 809      |
# |    total_timesteps  | 142640   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0704   |
# |    n_updates        | 8289     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 276      |
# |    ep_rew_mean      | 3.31     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15748    |
# |    fps              | 176      |
# |    time_elapsed     | 809      |
# |    total_timesteps  | 142700   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0579   |
# |    n_updates        | 8293     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 276      |
# |    ep_rew_mean      | 3.31     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15752    |
# |    fps              | 176      |
# |    time_elapsed     | 809      |
# |    total_timesteps  | 142720   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0641   |
# |    n_updates        | 8294     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 276      |
# |    ep_rew_mean      | 3.31     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15756    |
# |    fps              | 176      |
# |    time_elapsed     | 809      |
# |    total_timesteps  | 142756   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0568   |
# |    n_updates        | 8297     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 276      |
# |    ep_rew_mean      | 3.33     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15760    |
# |    fps              | 176      |
# |    time_elapsed     | 810      |
# |    total_timesteps  | 142792   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0525   |
# |    n_updates        | 8299     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 276      |
# |    ep_rew_mean      | 3.33     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15764    |
# |    fps              | 176      |
# |    time_elapsed     | 810      |
# |    total_timesteps  | 142812   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0681   |
# |    n_updates        | 8300     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 276      |
# |    ep_rew_mean      | 3.33     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15768    |
# |    fps              | 176      |
# |    time_elapsed     | 810      |
# |    total_timesteps  | 142864   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0389   |
# |    n_updates        | 8303     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 277      |
# |    ep_rew_mean      | 3.34     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15772    |
# |    fps              | 176      |
# |    time_elapsed     | 810      |
# |    total_timesteps  | 142880   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0427   |
# |    n_updates        | 8304     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 277      |
# |    ep_rew_mean      | 3.34     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15776    |
# |    fps              | 176      |
# |    time_elapsed     | 810      |
# |    total_timesteps  | 142920   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0431   |
# |    n_updates        | 8307     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 277      |
# |    ep_rew_mean      | 3.35     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15780    |
# |    fps              | 176      |
# |    time_elapsed     | 811      |
# |    total_timesteps  | 142956   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0285   |
# |    n_updates        | 8309     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 278      |
# |    ep_rew_mean      | 3.36     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15784    |
# |    fps              | 176      |
# |    time_elapsed     | 811      |
# |    total_timesteps  | 142976   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0511   |
# |    n_updates        | 8310     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 278      |
# |    ep_rew_mean      | 3.36     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15788    |
# |    fps              | 176      |
# |    time_elapsed     | 811      |
# |    total_timesteps  | 143032   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0299   |
# |    n_updates        | 8314     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 278      |
# |    ep_rew_mean      | 3.36     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15792    |
# |    fps              | 176      |
# |    time_elapsed     | 811      |
# |    total_timesteps  | 143064   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.067    |
# |    n_updates        | 8316     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 278      |
# |    ep_rew_mean      | 3.36     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15796    |
# |    fps              | 176      |
# |    time_elapsed     | 811      |
# |    total_timesteps  | 143096   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.047    |
# |    n_updates        | 8318     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 278      |
# |    ep_rew_mean      | 3.36     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15800    |
# |    fps              | 176      |
# |    time_elapsed     | 812      |
# |    total_timesteps  | 143124   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.055    |
# |    n_updates        | 8320     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 277      |
# |    ep_rew_mean      | 3.35     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15804    |
# |    fps              | 176      |
# |    time_elapsed     | 812      |
# |    total_timesteps  | 143156   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.119    |
# |    n_updates        | 8322     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 277      |
# |    ep_rew_mean      | 3.35     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15808    |
# |    fps              | 176      |
# |    time_elapsed     | 812      |
# |    total_timesteps  | 143200   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0316   |
# |    n_updates        | 8324     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 277      |
# |    ep_rew_mean      | 3.35     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15812    |
# |    fps              | 176      |
# |    time_elapsed     | 813      |
# |    total_timesteps  | 143232   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.022    |
# |    n_updates        | 8326     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 277      |
# |    ep_rew_mean      | 3.35     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15816    |
# |    fps              | 176      |
# |    time_elapsed     | 813      |
# |    total_timesteps  | 143268   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0279   |
# |    n_updates        | 8329     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 277      |
# |    ep_rew_mean      | 3.35     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15820    |
# |    fps              | 176      |
# |    time_elapsed     | 814      |
# |    total_timesteps  | 143344   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0704   |
# |    n_updates        | 8333     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 277      |
# |    ep_rew_mean      | 3.35     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15824    |
# |    fps              | 176      |
# |    time_elapsed     | 814      |
# |    total_timesteps  | 143384   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0678   |
# |    n_updates        | 8336     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 277      |
# |    ep_rew_mean      | 3.35     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15828    |
# |    fps              | 176      |
# |    time_elapsed     | 814      |
# |    total_timesteps  | 143452   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.055    |
# |    n_updates        | 8340     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 277      |
# |    ep_rew_mean      | 3.35     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15832    |
# |    fps              | 176      |
# |    time_elapsed     | 814      |
# |    total_timesteps  | 143464   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.019    |
# |    n_updates        | 8341     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 277      |
# |    ep_rew_mean      | 3.35     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15836    |
# |    fps              | 176      |
# |    time_elapsed     | 814      |
# |    total_timesteps  | 143500   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.00888  |
# |    n_updates        | 8343     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 278      |
# |    ep_rew_mean      | 3.38     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15840    |
# |    fps              | 176      |
# |    time_elapsed     | 815      |
# |    total_timesteps  | 143540   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0592   |
# |    n_updates        | 8346     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 280      |
# |    ep_rew_mean      | 3.41     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15844    |
# |    fps              | 176      |
# |    time_elapsed     | 815      |
# |    total_timesteps  | 143572   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0415   |
# |    n_updates        | 8348     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 280      |
# |    ep_rew_mean      | 3.41     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15848    |
# |    fps              | 176      |
# |    time_elapsed     | 815      |
# |    total_timesteps  | 143620   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0533   |
# |    n_updates        | 8351     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 280      |
# |    ep_rew_mean      | 3.41     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15852    |
# |    fps              | 176      |
# |    time_elapsed     | 815      |
# |    total_timesteps  | 143636   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0433   |
# |    n_updates        | 8352     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 280      |
# |    ep_rew_mean      | 3.42     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15856    |
# |    fps              | 176      |
# |    time_elapsed     | 815      |
# |    total_timesteps  | 143676   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0823   |
# |    n_updates        | 8354     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 277      |
# |    ep_rew_mean      | 3.34     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15860    |
# |    fps              | 176      |
# |    time_elapsed     | 816      |
# |    total_timesteps  | 143716   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.037    |
# |    n_updates        | 8357     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 277      |
# |    ep_rew_mean      | 3.34     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15864    |
# |    fps              | 176      |
# |    time_elapsed     | 816      |
# |    total_timesteps  | 143736   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0892   |
# |    n_updates        | 8358     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 277      |
# |    ep_rew_mean      | 3.34     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15868    |
# |    fps              | 176      |
# |    time_elapsed     | 816      |
# |    total_timesteps  | 143800   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0647   |
# |    n_updates        | 8362     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 277      |
# |    ep_rew_mean      | 3.34     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15872    |
# |    fps              | 176      |
# |    time_elapsed     | 816      |
# |    total_timesteps  | 143820   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0475   |
# |    n_updates        | 8363     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 277      |
# |    ep_rew_mean      | 3.34     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15876    |
# |    fps              | 176      |
# |    time_elapsed     | 816      |
# |    total_timesteps  | 143852   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0503   |
# |    n_updates        | 8365     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 274      |
# |    ep_rew_mean      | 3.29     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15880    |
# |    fps              | 176      |
# |    time_elapsed     | 816      |
# |    total_timesteps  | 143900   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0536   |
# |    n_updates        | 8368     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 274      |
# |    ep_rew_mean      | 3.25     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15884    |
# |    fps              | 176      |
# |    time_elapsed     | 817      |
# |    total_timesteps  | 143932   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.059    |
# |    n_updates        | 8370     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 274      |
# |    ep_rew_mean      | 3.25     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15888    |
# |    fps              | 176      |
# |    time_elapsed     | 817      |
# |    total_timesteps  | 143984   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0449   |
# |    n_updates        | 8373     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 274      |
# |    ep_rew_mean      | 3.25     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15892    |
# |    fps              | 176      |
# |    time_elapsed     | 817      |
# |    total_timesteps  | 144016   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0426   |
# |    n_updates        | 8375     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 273      |
# |    ep_rew_mean      | 3.22     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15896    |
# |    fps              | 176      |
# |    time_elapsed     | 817      |
# |    total_timesteps  | 144048   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0501   |
# |    n_updates        | 8377     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 272      |
# |    ep_rew_mean      | 3.22     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15900    |
# |    fps              | 176      |
# |    time_elapsed     | 817      |
# |    total_timesteps  | 144096   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0967   |
# |    n_updates        | 8380     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 273      |
# |    ep_rew_mean      | 3.23     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15904    |
# |    fps              | 176      |
# |    time_elapsed     | 818      |
# |    total_timesteps  | 144128   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0754   |
# |    n_updates        | 8382     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 273      |
# |    ep_rew_mean      | 3.23     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15908    |
# |    fps              | 176      |
# |    time_elapsed     | 818      |
# |    total_timesteps  | 144196   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.102    |
# |    n_updates        | 8387     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 273      |
# |    ep_rew_mean      | 3.23     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15912    |
# |    fps              | 176      |
# |    time_elapsed     | 818      |
# |    total_timesteps  | 144216   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0318   |
# |    n_updates        | 8388     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 273      |
# |    ep_rew_mean      | 3.23     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15916    |
# |    fps              | 176      |
# |    time_elapsed     | 818      |
# |    total_timesteps  | 144236   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0776   |
# |    n_updates        | 8389     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 273      |
# |    ep_rew_mean      | 3.22     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15920    |
# |    fps              | 176      |
# |    time_elapsed     | 819      |
# |    total_timesteps  | 144296   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0239   |
# |    n_updates        | 8393     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 273      |
# |    ep_rew_mean      | 3.22     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15924    |
# |    fps              | 176      |
# |    time_elapsed     | 819      |
# |    total_timesteps  | 144316   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0886   |
# |    n_updates        | 8394     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 273      |
# |    ep_rew_mean      | 3.22     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15928    |
# |    fps              | 176      |
# |    time_elapsed     | 819      |
# |    total_timesteps  | 144372   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0324   |
# |    n_updates        | 8398     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 272      |
# |    ep_rew_mean      | 3.21     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15932    |
# |    fps              | 176      |
# |    time_elapsed     | 819      |
# |    total_timesteps  | 144408   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0621   |
# |    n_updates        | 8400     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 272      |
# |    ep_rew_mean      | 3.21     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15936    |
# |    fps              | 176      |
# |    time_elapsed     | 819      |
# |    total_timesteps  | 144420   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0375   |
# |    n_updates        | 8401     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 272      |
# |    ep_rew_mean      | 3.2      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15940    |
# |    fps              | 176      |
# |    time_elapsed     | 819      |
# |    total_timesteps  | 144452   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0358   |
# |    n_updates        | 8403     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 272      |
# |    ep_rew_mean      | 3.2      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15944    |
# |    fps              | 176      |
# |    time_elapsed     | 820      |
# |    total_timesteps  | 144480   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0348   |
# |    n_updates        | 8404     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 272      |
# |    ep_rew_mean      | 3.2      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15948    |
# |    fps              | 176      |
# |    time_elapsed     | 820      |
# |    total_timesteps  | 144536   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0817   |
# |    n_updates        | 8408     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 272      |
# |    ep_rew_mean      | 3.19     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15952    |
# |    fps              | 176      |
# |    time_elapsed     | 820      |
# |    total_timesteps  | 144556   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0106   |
# |    n_updates        | 8409     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 272      |
# |    ep_rew_mean      | 3.19     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 15956    |
# |    fps              | 176      |
# |    time_elapsed     | 820      |
# |    total_timesteps  | 144576   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0637   |
# |    n_updates        | 8410     |
# ----------------------------------
# ----------------------------------
# ...
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16808    |
# |    fps              | 75       |
# |    time_elapsed     | 2011     |
# |    total_timesteps  | 151904   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0496   |
# |    n_updates        | 8868     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 251      |
# |    ep_rew_mean      | 2.53     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16812    |
# |    fps              | 75       |
# |    time_elapsed     | 2012     |
# |    total_timesteps  | 151960   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0404   |
# |    n_updates        | 8872     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 251      |
# |    ep_rew_mean      | 2.53     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16816    |
# |    fps              | 75       |
# |    time_elapsed     | 2012     |
# |    total_timesteps  | 152008   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0546   |
# |    n_updates        | 8875     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 251      |
# |    ep_rew_mean      | 2.53     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16820    |
# |    fps              | 75       |
# |    time_elapsed     | 2012     |
# |    total_timesteps  | 152044   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0463   |
# |    n_updates        | 8877     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 251      |
# |    ep_rew_mean      | 2.53     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16824    |
# |    fps              | 75       |
# |    time_elapsed     | 2012     |
# |    total_timesteps  | 152076   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.075    |
# |    n_updates        | 8879     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 252      |
# |    ep_rew_mean      | 2.55     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16828    |
# |    fps              | 75       |
# |    time_elapsed     | 2013     |
# |    total_timesteps  | 152184   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0597   |
# |    n_updates        | 8886     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 258      |
# |    ep_rew_mean      | 2.75     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16832    |
# |    fps              | 75       |
# |    time_elapsed     | 2013     |
# |    total_timesteps  | 152208   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0304   |
# |    n_updates        | 8887     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 258      |
# |    ep_rew_mean      | 2.75     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16836    |
# |    fps              | 75       |
# |    time_elapsed     | 2013     |
# |    total_timesteps  | 152256   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0412   |
# |    n_updates        | 8890     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 258      |
# |    ep_rew_mean      | 2.75     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16840    |
# |    fps              | 75       |
# |    time_elapsed     | 2013     |
# |    total_timesteps  | 152284   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0486   |
# |    n_updates        | 8892     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 258      |
# |    ep_rew_mean      | 2.75     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16844    |
# |    fps              | 75       |
# |    time_elapsed     | 2013     |
# |    total_timesteps  | 152304   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0417   |
# |    n_updates        | 8893     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 258      |
# |    ep_rew_mean      | 2.76     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16848    |
# |    fps              | 75       |
# |    time_elapsed     | 2013     |
# |    total_timesteps  | 152356   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0532   |
# |    n_updates        | 8897     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 258      |
# |    ep_rew_mean      | 2.78     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16852    |
# |    fps              | 75       |
# |    time_elapsed     | 2014     |
# |    total_timesteps  | 152384   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0734   |
# |    n_updates        | 8898     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 258      |
# |    ep_rew_mean      | 2.78     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16856    |
# |    fps              | 75       |
# |    time_elapsed     | 2014     |
# |    total_timesteps  | 152452   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.054    |
# |    n_updates        | 8903     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 258      |
# |    ep_rew_mean      | 2.78     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16860    |
# |    fps              | 75       |
# |    time_elapsed     | 2014     |
# |    total_timesteps  | 152480   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.058    |
# |    n_updates        | 8904     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 258      |
# |    ep_rew_mean      | 2.78     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16864    |
# |    fps              | 75       |
# |    time_elapsed     | 2015     |
# |    total_timesteps  | 152516   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0505   |
# |    n_updates        | 8907     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 259      |
# |    ep_rew_mean      | 2.8      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16868    |
# |    fps              | 75       |
# |    time_elapsed     | 2015     |
# |    total_timesteps  | 152564   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.00869  |
# |    n_updates        | 8910     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 259      |
# |    ep_rew_mean      | 2.8      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16872    |
# |    fps              | 75       |
# |    time_elapsed     | 2016     |
# |    total_timesteps  | 152660   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0359   |
# |    n_updates        | 8916     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 262      |
# |    ep_rew_mean      | 2.88     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16876    |
# |    fps              | 75       |
# |    time_elapsed     | 2016     |
# |    total_timesteps  | 152700   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0414   |
# |    n_updates        | 8918     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 262      |
# |    ep_rew_mean      | 2.88     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16880    |
# |    fps              | 75       |
# |    time_elapsed     | 2016     |
# |    total_timesteps  | 152748   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0403   |
# |    n_updates        | 8921     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 263      |
# |    ep_rew_mean      | 2.91     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16884    |
# |    fps              | 75       |
# |    time_elapsed     | 2017     |
# |    total_timesteps  | 152816   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.114    |
# |    n_updates        | 8925     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 264      |
# |    ep_rew_mean      | 2.93     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16888    |
# |    fps              | 75       |
# |    time_elapsed     | 2017     |
# |    total_timesteps  | 152912   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0486   |
# |    n_updates        | 8931     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 264      |
# |    ep_rew_mean      | 2.93     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16892    |
# |    fps              | 75       |
# |    time_elapsed     | 2017     |
# |    total_timesteps  | 152932   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0171   |
# |    n_updates        | 8933     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 265      |
# |    ep_rew_mean      | 2.95     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16896    |
# |    fps              | 75       |
# |    time_elapsed     | 2017     |
# |    total_timesteps  | 152964   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0538   |
# |    n_updates        | 8935     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 266      |
# |    ep_rew_mean      | 2.97     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16900    |
# |    fps              | 75       |
# |    time_elapsed     | 2018     |
# |    total_timesteps  | 152984   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0614   |
# |    n_updates        | 8936     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 266      |
# |    ep_rew_mean      | 2.97     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16904    |
# |    fps              | 75       |
# |    time_elapsed     | 2018     |
# |    total_timesteps  | 153028   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0277   |
# |    n_updates        | 8939     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 266      |
# |    ep_rew_mean      | 2.99     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16908    |
# |    fps              | 75       |
# |    time_elapsed     | 2018     |
# |    total_timesteps  | 153060   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0385   |
# |    n_updates        | 8941     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 266      |
# |    ep_rew_mean      | 2.99     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16912    |
# |    fps              | 75       |
# |    time_elapsed     | 2018     |
# |    total_timesteps  | 153072   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 266      |
# |    ep_rew_mean      | 2.99     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16916    |
# |    fps              | 75       |
# |    time_elapsed     | 2018     |
# |    total_timesteps  | 153136   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0495   |
# |    n_updates        | 8945     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 267      |
# |    ep_rew_mean      | 2.99     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16920    |
# |    fps              | 75       |
# |    time_elapsed     | 2019     |
# |    total_timesteps  | 153196   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0386   |
# |    n_updates        | 8949     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 267      |
# |    ep_rew_mean      | 2.99     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16924    |
# |    fps              | 75       |
# |    time_elapsed     | 2019     |
# |    total_timesteps  | 153228   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0183   |
# |    n_updates        | 8951     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 269      |
# |    ep_rew_mean      | 3.05     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16928    |
# |    fps              | 75       |
# |    time_elapsed     | 2019     |
# |    total_timesteps  | 153296   |
# | train/              |          |
# |    learning_rate    | 1e-05    |
# |    loss             | 0.0182   |
# |    n_updates        | 8955     |
# ----------------------------------

# %% [markdown]
# 5. After training, These are functions to record and show videos.

# %%
import base64
from pathlib import Path

from IPython import display as ipythondisplay
from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv


def record_video(env_id, model, video_length=500, prefix="", video_folder="videos/"):
    """
    :param env_id: (str)
    :param model: (RL model)
    :param video_length: (int)
    :param prefix: (str)
    :param video_folder: (str)
    """

    vec_env = make_atari_env(env_id, n_envs=4, seed=0)
    vec_env = VecFrameStack(vec_env, n_stack=4)

    # Start the video at step=0 and record 500 steps
    eval_env = VecVideoRecorder(
        vec_env,
        video_folder=video_folder,
        record_video_trigger=lambda step: step == 0,
        video_length=video_length,
        name_prefix=prefix,
    )

    obs = eval_env.reset()
    for _ in range(video_length):
        action, _ = model.predict(obs)
        obs, _, _, _ = eval_env.step(action)

    # Close the video recorder
    eval_env.close()

def show_videos(video_path="", prefix=""):
    """
    Taken from https://github.com/eleurent/highway-env

    :param video_path: (str) Path to the folder containing videos
    :param prefix: (str) Filter the video, showing only the only starting with this prefix
    """
    html = []
    for mp4 in Path(video_path).glob("{}*.mp4".format(prefix)):
        video_b64 = base64.b64encode(mp4.read_bytes())
        html.append(
            """<video alt="{}" autoplay
                    loop controls style="height: 400px;">
                    <source src="data:video/mp4;base64,{}" type="video/mp4" />
                </video>""".format(
                mp4, video_b64.decode("ascii")
            )
        )
    ipythondisplay.display(ipythondisplay.HTML(data="<br>".join(html)))

# %%
record_video("BreakoutDeterministic-v4", model, video_length=500, prefix="bov4")

show_videos("videos", prefix="bov4")
